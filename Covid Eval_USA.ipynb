# %% [markdown]
# ## Introduction
#
# This dataset is for the 2019 Novel Coronavirus Visual Dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering (JHU CSSE). Also, Supported by ESRI Living Atlas Team and the Johns Hopkins University Applied Physics Lab (JHU APL).
#
#
# Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease. Middle East Respiratory Syndrome (MERS-CoV) and Severe Acute Respiratory Syndrome (SARS-CoV) were such severe cases with the world already has faced. SARS-CoV-2 (n-coronavirus) is the new virus of the coronavirus family, which first discovered in 2019, which has not been identified in humans before.
#
# It is a contiguous virus which started from Wuhan in December 2019. Which later declared as Pandemic by WHO due to high rate spreads throughout the world. Currently (on the date 20 May 2020), this leads to a total of 300K+ Deaths across the globe, including 90K+ deaths alone in USA.The dataset  is provided to identify the deaths and recovered cases.
#
#
#
# Field description:
#
#
# Province_State - The name of the State within the USA.
#
#
# Country_Region - The name of the Country (US).
#
#
# Last_Update - The most recent date the file was pushed.
#
#
# Lat - Latitude.
#
#
# Long_ - Longitude.
#
#
# Confirmed - Aggregated confirmed case count for the state.
#
#
# Deaths - Aggregated Death case count for the state.
#
#
# Recovered - Aggregated Recovered case count for the state.
#
#
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
#
#
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
#
#
# Incident_Rate - confirmed cases per 100,000 persons.
#
#
# People_Tested - Total number of people who have been tested.
#
#
# People_Hospitalized - Total number of people hospitalized.
#
#
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
#
#
# UID - Unique Identifier for each row entry.
#
#
# ISO3 - Officialy assigned country code identifiers.
#
#
# Testing_Rate - Total number of people tested per 100,000 persons.
#
#
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.
#
# ## Problem Statement :
#
# To predict the deaths happened in different states of USA on 2020-05-21.

# %% [markdown]
# ### Importing required library.

# %%
import numpy as np 
import pandas as pd 

from plotly.offline import iplot
import plotly.graph_objs as go

import plotly.figure_factory as ff
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
covid_daily_df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/COVID_19_Datasets/master/csse_covid_19_daily_reports_us.csv")
covid_daily_df #Loading the dataset
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
covid_daily_df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000      58.000000     58.000000     42.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.887035   49.754449   52562.031122   4084.750891  11674.490020
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.594600 -101.165775    2596.000000     74.000000    970.000000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.361650  -76.970625   29395.500000   1394.250000   7326.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      56.000000   5.600000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     402.682539   2.987834e+05
# ...

# %% [markdown]
# 1. As we can see counts are not same, so there is possiblity of missing values in dataset. We need to treat them further.

# %%
covid_daily_df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
#eliminating NaN values in recovered
covid_daily_df["Recovered"] = covid_daily_df["Confirmed"]-(covid_daily_df["Deaths"]+covid_daily_df["Active"])
covid_daily_df["Recovered"].isnull().sum()
# Out:
# 0

# %%
covid_daily_df.loc[9,'Lat'] = 35.27
covid_daily_df.loc[9,'Long_'] = 139.38
# above are latitude and longitude for Diamond Princess Docked at yokohama port
covid_daily_df.loc[13,'Lat'] = 37.47
covid_daily_df.loc[13,'Long_'] = 122.17
# above are latitude and longitude for Grand Princess Docked at Oakland port
covid_daily_df.Lat.isnull().sum() , covid_daily_df.Long_.isnull().sum()
# Out:
# (0, 0)

# %%
covid_daily_df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      0
# Long_                    0
# Confirmed                0
# Deaths                   0
# Recovered                0
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [markdown]
# Treating the null values
# 1. In Columns Incident rate, Mortality Rate, Testing Rate and People tested we will fill the null values by median.
# 2. For columns People Hospitalized and Hospitalization Rate 75th Quantile is prefered for filling the null values.

# %%
covid_daily_df['Incident_Rate'] = covid_daily_df['Incident_Rate'].fillna(covid_daily_df.Incident_Rate.median())
covid_daily_df['People_Tested'] = covid_daily_df['People_Tested'].fillna(covid_daily_df.People_Tested.median())

covid_daily_df['Mortality_Rate'] = covid_daily_df['Mortality_Rate'].fillna(covid_daily_df.Mortality_Rate.median())
covid_daily_df['Testing_Rate'] = covid_daily_df['Testing_Rate'].fillna(covid_daily_df.Mortality_Rate.median())

covid_daily_df['People_Hospitalized'] = covid_daily_df['People_Hospitalized'].fillna(covid_daily_df.People_Hospitalized.quantile(q=0.75))
covid_daily_df['Hospitalization_Rate'] = covid_daily_df['People_Hospitalized'].fillna(covid_daily_df.Hospitalization_Rate.quantile(q=0.75))
covid_daily_df.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %% [markdown]
# No null values left in dataset.

# %%
covid_daily_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   58 non-null     float64
#  4   Long_                 58 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             58 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         58 non-null     float64
#  11  People_Tested         58 non-null     float64
#  12  People_Hospitalized   58 non-null     float64
#  13  Mortality_Rate        58 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
covid_daily_df.Last_Update = pd.to_datetime(covid_daily_df["Last_Update"]) # Changing data type of last UPdate column

# %%
covid_daily_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     datetime64[ns]
#  3   Lat                   58 non-null     float64
#  4   Long_                 58 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             58 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         58 non-null     float64
#  11  People_Tested         58 non-null     float64
#  12  People_Hospitalized   58 non-null     float64
#  13  Mortality_Rate        58 non-null     float64
# ...

# %%
df = covid_daily_df.drop(["Country_Region","UID","ISO3","Lat","Long_"],axis=1)
sns.pairplot(df,palette="mako")

# %%
sns.relplot(x="Deaths",y="Province_State",
            hue="Recovered",size="Confirmed",
            data=covid_daily_df, 
            height= 10,
            palette = "cividis")

# %% [markdown]
# The graph shows statewise mortality rate, recoverd and confirmed cases as well.

# %%
x = covid_daily_df.Province_State

# %%
y1 = covid_daily_df.Confirmed
y2= covid_daily_df.Deaths
y3 = covid_daily_df.Recovered

# %%
plt.figure(figsize=(12, 6))
plt.plot(x,y1,label = "Confirmed")
plt.plot(x,y2,label="Deaths")
plt.plot(x,y3,label="Recovered")
plt.xticks(rotation = 90)

plt.legend()

# %% [markdown]
# New York have highest number of Death and Confirmed cases
# > Recovery Rate is consistently better than Deaths and on-par with Confirmed

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()
covid_daily_df.Province_State = label_encoder.fit_transform(covid_daily_df['Province_State'])
covid_daily_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c569664e982c> in <module>
#       1 from sklearn import preprocessing
#       2 label_encoder = preprocessing.LabelEncoder()
# ----> 3 covid_daily_df.Province_State = label_encoder.fit_transform(covid_daily_df['Province_State'])
#       4 covid_daily_df
#
# NameError: name 'covid_daily_df' is not defined

# %%
covid_daily_df.Last_Update.unique() , covid_daily_df.Country_Region.unique() , covid_daily_df.ISO3.unique()
# Out:
# (array(['2020-05-21T02:32:54.000000000'], dtype='datetime64[ns]'),
#  array(['US'], dtype=object),
#  array(['USA', 'ASM', 'GUM', 'MNP', 'PRI', 'VIR'], dtype=object))

# %%
corr = covid_daily_df.corr()
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr,cmap="icefire",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Country_Region, Last_update Are same Throughout the dataset and thus will not affect Accuracy of model to be trained

# %%
covid_daily_df.drop(["Country_Region","Last_Update"],axis=1,inplace=True)

# %%
from sklearn import preprocessing  
label_encoder = preprocessing.LabelEncoder()
covid_daily_df['ISO3']= label_encoder.fit_transform(covid_daily_df['ISO3'])

# %%
X = covid_daily_df.loc[:,covid_daily_df.columns != "Deaths"]
Y = covid_daily_df["Deaths"]

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Selecting the best model

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    train_size=0.75,
                                                    random_state=4)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet 
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import RandomForestRegressor 
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

Acc_matrix = []

Model_dict = {
"Linear Regression": LinearRegression(),
"Ridge Regression": Ridge(),
"Lasso Regression": Lasso(),
"ElasticNet": ElasticNet(),
"Bayesian Ridge Regression": BayesianRidge(),
"Random Forest Regressor" : RandomForestRegressor() ,
"Decision Tree Regressor": DecisionTreeRegressor(),
"Support Vector Regressor": SVR()
}

# %%
for i in Model_dict:
    Model_dict[i].fit(X_train, y_train)
    print("Score Of",i,"is : ",Model_dict[i].score(X_test, y_test)*100,'%\n')
    predict = Model_dict[i].predict(X_test)
    print("Errors : \n")
    print("Mean Absolute Error : ", mean_absolute_error(y_test,predict))
    print("Mean Squared Error : ", round(mean_squared_error(y_test, predict,squared=False), 2))
    Acc_matrix.append("{:.2f}".format( r2_score(y_test, predict)))
    
    print("R2 Score : ", r2_score(y_test, predict))
    print("\n****************************\n")
# Out:
# Score Of Linear Regression is :  100.0 %
#
# Errors :
#
# Mean Absolute Error :  1.9828050312753477e-11
# Mean Squared Error :  0.0
# R2 Score :  1.0
#
# ****************************
#
# Score Of Ridge Regression is :  99.99999999999866 %
#
# Errors :
#
# Mean Absolute Error :  0.00015852971756930383
# Mean Squared Error :  0.0
# R2 Score :  0.9999999999999867
#
# ****************************
#
# Score Of Lasso Regression is :  95.10670286282928 %
#
# Errors :
#
# Mean Absolute Error :  299.7801287688339
# Mean Squared Error :  393.07
# R2 Score :  0.9510670286282928
#
# ****************************
#
# Score Of ElasticNet is :  95.59092912767345 %
#
# Errors :
#
# Mean Absolute Error :  294.61913724983447
# Mean Squared Error :  373.12
# R2 Score :  0.9559092912767345
#
# ****************************
#
# Score Of Bayesian Ridge Regression is :  95.90606160270174 %
#
# Errors :
#
# Mean Absolute Error :  283.5974734510181
# Mean Squared Error :  359.53
# ...

# %% [markdown]
# ## CrossValidation

# %%
from sklearn.model_selection import cross_val_score
for i in Model_dict:
    score = cross_val_score(Model_dict[i],X_train,y_train,cv=4,scoring='r2')
    print("Score of",i," : \n\nScore :",score)
    print("Mean Score : ", score.mean())
    print("Standard Deviation : ", score.std())
    print("\n***************************\n")
# Out:
# Score of Linear Regression  :
#
# Score : [1. 1. 1. 1.]
# Mean Score :  1.0
# Standard Deviation :  0.0
#
# ***************************
#
# Score of Ridge Regression  :
#
# Score : [1. 1. 1. 1.]
# Mean Score :  0.9999999999994515
# Standard Deviation :  4.618043535684058e-13
#
# ***************************
#
# Score of Lasso Regression  :
#
# Score : [0.67995685 0.89135845 0.93630255 0.07916586]
# Mean Score :  0.6466959280773215
# Standard Deviation :  0.3416608027137418
#
# ***************************
#
# Score of ElasticNet  :
#
# Score : [0.67083783 0.89362369 0.96423411 0.07577698]
# Mean Score :  0.6511181509952879
# Standard Deviation :  0.3493768996354685
#
# ***************************
#
# Score of Bayesian Ridge Regression  :
#
# Score : [0.60215629 0.98290939 1.         0.1629696 ]
# Mean Score :  0.6870088214069852
# Standard Deviation :  0.34181050431691967
#
# ***************************
#
# Score of Random Forest Regressor  :
#
# ...

# %% [markdown]
# ### Comparing Score of above models

# %%
data = zip(Model_dict.keys(),Acc_matrix)
df_score = pd.DataFrame(data, columns = ['Model', 'R2_Score']) 
df_score.sort_values('R2_Score', ascending=False)
# Out:
#                        Model R2_Score
# 0          Linear Regression     1.00
# 1           Ridge Regression     1.00
# 3                 ElasticNet     0.96
# 4  Bayesian Ridge Regression     0.96
# 2           Lasso Regression     0.95
# 5    Random Forest Regressor     0.93
# 6    Decision Tree Regressor     0.85
# 7   Support Vector Regressor    -0.55

# %% [markdown]
# Ridge Regression have Accuracy Of 99.99%
#
# As well as Best RMSE of 0.0

# %% [markdown]
# ## Hyper-Parameter Tuning

# %%
parameters = {'alpha':[1,4,6,8, 10],
              'max_iter':[500,1000,1500],
              "solver":["auto", "svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"]}
GridSearchCV(Ridge(), param_grid=parameters).fit(X,Y).best_estimator_
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=500, normalize=False,
#       random_state=None, solver='auto', tol=0.001)

# %%
clf = Ridge(alpha=1, max_iter=500)
clf.fit(X_train, y_train)
print("Score is : ",clf.score(X_test, y_test)*100,'%\n')
predict = clf.predict(X_test)
print("Errors : \n")
print("Mean Absolute Error : ", mean_absolute_error(y_test,predict))
print("Mean Squared Error : ", round(mean_squared_error(y_test, predict,squared=False), 2))
Acc_matrix.append("{:.2f}".format( r2_score(y_test, predict)))
print("R2 Score : ", r2_score(y_test, predict))
# Out:
# Score is :  99.99999999999866 %
#
# Errors :
#
# Mean Absolute Error :  0.00015852971756930383
# Mean Squared Error :  0.0
# R2 Score :  0.9999999999999867

# %% [markdown]
# Ridge regression is giving us best accuracy so we will save this model.

# %% [markdown]
# ### Serialization

# %%
from joblib import dump, load
dump(clf, 'Covid_Ridge.joblib')
# Out:
# ['Covid_Ridge.joblib']
